# %% [markdown]
# # ex04_lti_wts
#
# Interactive notebook version of the Python example.
# Edit parameters and rerun cells to explore the model behavior.

# %% [markdown]
# ## MATLAB-style Sections
#
# - LTI model of a Coleman transformed wind turbine system
# - Closed-loop identification experiment
# - Prediction error method optimization (MATLAB reference)

# %% [markdown]
# ## Imports

# %%
from __future__ import annotations

import numpy as np
from _common import (
    estimate_varx_abcdk,
    print_case_summary,
    simulate_lti,
    stable_random_system,
    vaf_percent,
)

# %% [markdown]
# ## LTI Model Of A Coleman Transformed Wind Turbine System
# Generate a stable surrogate LTI wind turbine model for the interactive notebook port.

# %%
a, b, c, d, k = stable_random_system(n=7, r=2, l_out=3, seed=104)

# %% [markdown]
# ## Closed-Loop Identification Experiment
# Run the surrogate closed-loop experiment and estimate the subspace model.

# %%
n_samples = 10000
h = 0.1
rng = np.random.default_rng(104)
r_pitch = np.sign(rng.standard_normal(n_samples))
r_torque = 1e3 * np.sign(rng.standard_normal(n_samples))
u = np.column_stack((r_pitch, r_torque)).astype(np.float64)
e = 0.03 * rng.standard_normal((n_samples, 3))
y, _ = simulate_lti(a, b, c, d, u, k=k, e=e)
y_nom, _ = simulate_lti(a, b, c, d, u)
n = a.shape[0]
p = 50
f = 20
_, ai, bi, ci, di, _, _, _ = estimate_varx_abcdk(u, y, n, f, p)
yi, _ = simulate_lti(ai, bi, ci, di, u)

# %% [markdown]
# ## Prediction Error Method Optimization
# MATLAB refines the subspace model with PEM in this section. That PEM refinement step is not yet implemented in the notebook port.

# %% [markdown]
# ## Identification Results
# The MATLAB example visualizes identified poles and frequency responses here. The notebook currently reports a surrogate numerical summary instead.

# %%
print_case_summary("ex04-wts-surrogate", 0.0, vaf_percent(y_nom, yi), ai)
print(f"Sample time used: {h}")
